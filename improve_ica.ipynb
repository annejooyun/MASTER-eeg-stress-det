# %%
import numpy as np
import mne
import scipy.io

import utils.variables as v
from utils.valid_recs import get_valid_recs

# %%
dir = 'C:/Users/annej/OneDrive/Documents/GitHub/MASTER-eeg-stress-det/Data/ICA_data'
data_key = 'Clean_data'

valid_recs = get_valid_recs(data_type='ica', output_type = 'np')

for rec in valid_recs:
    sub_nr, ses_nr, run_nr = rec.split('_')

    # Load one recording
    filename = f"/sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}.mat"
    f = dir + filename
    data = scipy.io.loadmat(f)[data_key]*1e-6
    data = data[:,:75000]

    info = mne.create_info(8, v.SFREQ, ch_types= "eeg", verbose=None)
    ica_eeg = mne.io.RawArray(data, info)
    mne.rename_channels(ica_eeg.info, v.MAPPING)

    #ica_eeg.plot(title = f"ICA sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}")

    # Downsampling and adding another savgol filter
    new_ica = ica_eeg.copy().resample(sfreq = 128)
    new_ica = new_filter.savgol_filter(h_freq = 10)
    #new_filter.plot(title = f"NEW sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}")

    title = f"sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}"
    clean_data = new_ica.to_data_frame(scalings=1)
    clean_data = clean_data.to_numpy()
    clean_data = np.transpose(clean_data)
    clean_dict = {
        "Clean_data" : clean_data[1:, :]  #First column of dataFrames is not data
    }
    scipy.io.savemat(
        f'C:/Users/annej/OneDrive/Documents/GitHub/MASTER-eeg-stress-det/Data/New_ICA_data/{title}.mat', clean_dict)
# Out:
# ERROR:root:1) Failed to read data for recording P006_S002_001
# ERROR:root:1) Failed to read data for recording P006_S002_002
# Filtering out invalid recordings
#
# Data/ICA_data\sub-P010_ses-S001_run-001.mat not valid
# Data/ICA_data\sub-P013_ses-S001_run-001.mat not valid
# Data/ICA_data\sub-P013_ses-S001_run-002.mat not valid
# ERROR:root:1) Failed to read data for recording P028_S001_001
# ERROR:root:1) Failed to read data for recording P028_S001_002
# Data/ICA_data\sub-P020_ses-S001_run-001.mat not valid
# Data/ICA_data\sub-P023_ses-S002_run-002.mat not valid
# Returning valid recordings
#
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13

# %%
data = data[:,:75000]

info = mne.create_info(8, v.SFREQ, ch_types= "eeg", verbose=None)
ica_eeg = mne.io.RawArray(data, info)
mne.rename_channels(ica_eeg.info, v.MAPPING)

#ica_eeg.plot(title = f"ICA sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}")

new_filter = ica_eeg.copy().resample(sfreq = 128)
new_filter = new_filter.savgol_filter(h_freq = 10)
#new_filter.plot(title = f"NEW sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}")



'''
#Interpolating bad channels
#Doesn't pick up any bad channels

ica_interp = ica_eeg.copy().interpolate_bads(reset_bads=False)
ica_interp.plot(title = f"Interp sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}")

'''

'''
Common Average Reference
Seems to do little to no improvement on the data

car_eeg_data = np.empty(data.shape)

for i in range(v.NUM_CHANNELS):
    channel_mean = np.mean(data[i,:])
    print(f"channel mean for channel {i+1} is: {channel_mean}")
    car_row_ = data[i,:] - channel_mean
    car_row  = car_row_.reshape(1,75000)
    car_eeg_data[i,:] = car_row


car_eeg = mne.io.RawArray(car_eeg_data, info)
mne.rename_channels(car_eeg.info, v.MAPPING)
car_eeg.plot(title = f"CAR sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}")
'''
# Out:
# Creating RawArray with float64 data, n_channels=8, n_times=75000
#     Range : 0 ... 74999 =      0.000 ...   299.996 secs
# Ready.
# Using savgol length 13
# '\nCommon Average Reference\nSeems to do little to no improvement on the data\n\ncar_eeg_data = np.empty(data.shape)\n\nfor i in range(v.NUM_CHANNELS):\n    channel_mean = np.mean(data[i,:])\n    print(f"channel mean for channel {i+1} is: {channel_mean}")\n    car_row_ = data[i,:] - channel_mean\n    car_row  = car_row_.reshape(1,75000)\n    car_eeg_data[i,:] = car_row\n\n\ncar_eeg = mne.io.RawArray(car_eeg_data, info)\nmne.rename_channels(car_eeg.info, v.MAPPING)\ncar_eeg.plot(title = f"CAR sub-{sub_nr}_ses-{ses_nr}_run-{run_nr}")\n'
